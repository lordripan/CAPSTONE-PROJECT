# %%
#Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Answer-1-The population of each state/ut

# %% [markdown]
# #### This data has been collected from http://cyberjournalist.org.in/census/cenindia.html for year 2001 on population

# %%
dp=pd.read_csv(r"C:\Users\OM RAJ PANDEY\Documents\Population data-2001.csv")
dp.head(37)
# Out:
#     Unnamed: 0                       State   Population       Male   \
# 0          1.0           Jammu and Kashmir      10069917    5300574
# 1          2.0            Himachal Pradesh       6077248    3085256
# 2          3.0                      Punjab      24289296   12963362
# 3          4.0                  Chandigarh        900914     508224
# 4          5.0                 Uttaranchal       8479562    4316401
# 5          6.0                     Haryana      21082989   11327658
# 6          7.0                       Delhi      13782976    7570890
# 7          8.0                   Rajasthan      56473122   29381657
# 8          9.0               Uttar Pradesh     166052859   87466301
# 9         10.0                       Bihar      82878796   43153964
# 10        11.0                      Sikkim        540493     288217
# 11        12.0           Arunachal Pradesh       1091117     573951
# 12        13.0                    Nagaland       1988636    1041686
# ...

# %% [markdown]
# #### This data has been collected from https://censusindia.gov.in/census.website/data/census-tables for year 2011.So,for census
# #### counting has been done in the gap of every 10 years.So this data is for 2001 to 2011.

# %% [markdown]
# #### THE POUPLATION OF EACH STATE-2011

# %%
df=pd.read_csv(r"C:\Users\OM RAJ PANDEY\Desktop\POPULATION DATA-2011.csv")
df.head(37)
# Out:
#         COUNTRY/STATE/UT  YEAR    TOTAL PERSON          MALE        FEMALE
# 0                  INDIA  2011  1,21,08,54,977  62,32,70,258  58,75,84,719
# 1       HIMACHAL PRADESH  2011     1,25,41,302     66,40,662     59,00,640
# 2                 PUNJAB  2011     2,77,43,338   1,46,39,465   1,31,03,873
# 3             CHANDIGARH  2011       10,55,450      5,80,663      4,74,787
# 4            UTTARAKHAND  2011     1,00,86,292     51,37,773     49,48,519
# 5                HARYANA  2011     2,53,51,462   1,34,94,734   1,18,56,728
# 6           NCT OF DELHI  2011     1,67,87,941     89,87,326     78,00,615
# 7              RAJASTHAN  2011     6,85,48,437   3,55,50,997   3,29,97,440
# 8          UTTAR PRADESH  2011    19,98,12,341  10,44,80,510   9,53,31,831
# 9                  BIHAR  2011    10,40,99,452   5,42,78,157   4,98,21,295
# 10                SIKKIM  2011        6,10,577      3,23,070      2,87,507
# ...

# %% [markdown]
# ## ANSWER-2- The literacy rate of each state/ut

# %% [markdown]
# #### This data has been collected from https://socialjustice.gov.in/common/76669 for year 2001 on literacy rate of India

# %%
dl=pd.read_csv(r"C:\Users\OM RAJ PANDEY\Documents\Literacy rate-2001.csv")
dl.head(37)
# Out:
#                 State/UT Literacy Rate 2001 Unnamed: 2 Unnamed: 3
# 0                    NaN              Total         SC         PD
# 1       1. Uttar Pradesh               56.3       46.3       44.5
# 2         2. Maharashtra               76.9       71.9       57.6
# 3               3. Bihar                 47       28.5       37.2
# 4         4. West Bengal               68.6         59       52.7
# 5      5. Andhra Pradesh               60.5       53.5       44.2
# 6          6. Tamil Nadu               73.5       63.2       58.6
# 7      7. Madhya Pradesh               63.7       58.6       49.7
# 8           8. Rajasthan               60.1       52.2       45.3
# 9           9. Karnataka               66.6       52.9       50.3
# 10           10. Gujarat               69.1       70.5         54
# 11            11. Orissa               63.1       55.5       48.8
# 12            12. Kerala               90.9       82.7         67
# ...

# %% [markdown]
# #### LITERACY RATE IN EACH STATE-2011

# %% [markdown]
# #### This data has been collected from https://www.census2011.co.in/literacy.php for year 2011

# %%
df=pd.read_csv(r"C:\Users\OM RAJ PANDEY\Documents\Literacy rate.csv")
df.head(37)
# Out:
#     Index             Country/State/ut  Literacy   Male  Female  % Change
# 0       0                        India     74.04  82.14   65.46      8.66
# 1       1                       Kerala     94.00  96.11   92.07      3.14
# 2       2                  Lakshadweep     91.85  95.56   87.95      5.19
# 3       3                      Mizoram     91.33  93.35   89.27      2.53
# 4       4                          Goa     88.70  92.65   84.66      6.69
# 5       5                      Tripura     87.22  91.53   82.73     14.03
# 6       6                Daman and Diu     87.10  91.54   79.55      8.92
# 7       7  Andaman and Nicobar Islands     86.63  90.27   82.43      5.33
# 8       8                        Delhi     86.21  90.94   80.76      4.54
# 9       9                   Chandigarh     86.05  89.99   81.19      4.11
# 10     10                   Puducherry     85.85  91.26   80.67      4.61
# 11     11             Himachal Pradesh     82.80  89.53   75.93      6.32
# ...

# %% [markdown]
# #### ANSWER NO.3-THE AREA OF EACH STATE/UT

# %% [markdown]
# #### This data has been collected form https://censusindia.gov.in/census.website/data/census-tables for year 2001

# %%
da=pd.read_excel(r"C:\Users\OM RAJ PANDEY\Desktop\PC01_A01_Statement1.xls")
da.head(40)
# Out:
#     Sl. No.      State/Union Territory #     Area in sq. km.      Unnamed: 3  \
# 0       NaN                          NaN               Total           Rural
# 1       1.0                            2                   3               4
# 2       NaN                          NaN                 NaN             NaN
# 3       NaN                 INDIA  @ + $             3287263  3,118,237.74 *
# 4       NaN                          NaN                 NaN             NaN
# 5       1.0            Jammu & Kashmir @              222236       221272.69
# 6       2.0             Himachal Pradesh               55673        55431.29
# 7       3.0                       Punjab               50362        48265.38
# 8       4.0                 Chandigarh #                 114           34.66
# 9       5.0                  Uttaranchal               53483        52686.23
# 10      6.0                      Haryana               44212        42931.63
# ...

# %% [markdown]
# #### This data has been collected from https://www.indiastat.com/specimen-tables/geographical-data for year 2011

# %%
da=pd.read_csv(r"C:\Users\OM RAJ PANDEY\Documents\Area.csv")
# ### 22. West bengal population was increased by 1,10,54,944,  literacy rate was increased by 7.66% and area is same.
# ### 23. Assam population was increased by 45,67,169,  literacy rate was increased by 8.89% and area is same.
# ### 24. Karnataka population was increased by 83,61,339,  literacy rate was increased by 8.76% and area is same.
# ### 25. Andhra pradesh population was increased by 88,53,236,  literacy rate was increased by 6.52% and area is same.
# ### 26. Maharashtra population was increased by 1,56,22,086,  literacy rate was increased by 5.44% and area is same.
# ### 27. Dadar & Nagar Haveli population was increased by 1,23,258,  literacy rate was increased by 18.64% and area is same.
# ### 28. Daman & Diu population was increased by 85,188,  literacy rate was increased by 8.9% and area is decreased by 1 sq.km.
# ### 29. Gujrat population was increased by 98,42,700,  literacy rate was increased by 5.62% and area is increased by 220 sq.km.
# ### 30. Andaman & Nicobar island population was increased by 24,316,  literacy rate was increased by 5.33% and area is same.
# ### 31. Pondicherry population was increased by 2,74,124,  literacy rate was increased by 4.65% and area is increased by 11 sq.km.
# ### 32. Tamilnadu population was increased by 1,00,36,191  literacy rate was increased by 6.59% and area is increased by 2 sq.km.
# ### 33. Kerala population was increased by 15,67,442,  literacy rate was increased by 3.1% and area is decreased by 11 sq.km.
# ### 34. Lakshadweep population was increased by 3,878,  literacy rate was increased by 5.15% and area is decreased by 2 sq.km.
# ### 35. Goa population was increased by 1,14,547,  literacy rate was increased by 6.7% and area is same.
# ##  Overall we can say  that in between 2001 and 2011 the Indian population increased to 1.21 billion with a decadal growth of 17.70%. Adult literacy rate increased to 74.04% with a decadal growth of 9.21%.

# %% [markdown]
# # Analysis on observation:
# ### India has world's geographical area 2.4% and world's population percentage 17.64.
# ### Lowest populatin growth rate in Lakshadweep.
# ### Highest populatin growth rate in Dadar & Nagar Haveli.
# ### Highest Urban population in Maharashtra
# ### Highest population state is Uttar pradesh
# ### Lowest population state is Sikkim
# ### Top 4 states in population Uttar pradesh, Maharashtra, Bihar, West Bengal
# ### Highest literacy rate increase in Dadar & Nagar Haveli in UT and in states in Bihar
# ### Highest literacy rate state is Keral
# ### Lowest literacy rate state is Bihar
# ### Top 5 states in literacy rate Keral, Lakshdweep, Mizoram, Goa, Tripura
# ### Bottom 5 states in literacy rate Bihar, Arunachal pradesh, Rajasthan, Jharkhand, Andhra pradesh
# ### Highest area increase between 2010 and 2011 in Gujrat.
# ### Lowest area increase between 2010 and 2011 in Chattisgarh
# ### Highest area decrease between 2010 and 2011 in Keral
# ### Lowest area decrease between 2010 and 2011 in Daman & Diu
# ### Most of the states has same area
# ### India's Total population is 1,21,08,54,977, total number of male 62,32,70,258, total population of female 58,75,84,719 and density is 382 per sq km according to 2011 census data.
